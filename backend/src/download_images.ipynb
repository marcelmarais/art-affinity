# %%
import os
os.chdir('/content/drive/MyDrive/art-finder/backend/src')
from scraper.image_downloader import download_images
# Out:
# Streaming output truncated to the last 5000 lines.
# Successfully downloaded b3d1f8964e3eafe1e3c24beb1572fc46.jpg
# Successfully downloaded 52fb4627c8ccc7a2e6736d0badd6fb83.jpg
# Successfully downloaded 8f5d4e29e1964c15955ecec74da0acb3.jpg
# Successfully downloaded dacab9f0467f82a49f27d98b15b68e59.jpg
# Successfully downloaded 08febd0793405c913908af0c1a2347e2.jpg
# Successfully downloaded a41572b6b5493a20414de11a85645903.jpg
# Successfully downloaded eaf6d1dc01212ceffb3d8e45c9a361ef.jpg
# Successfully downloaded 00624e60449629139ef321f2c27751e4.jpg
# Successfully downloaded a6dbc83836b9467eca4b071c970893b3.jpg
# Successfully downloaded ccb72e8d1d19736fc9537e19bd631fad.jpg
# Successfully downloaded 043c7e20d46c7605c87a00d1ffe68170.jpg
# Successfully downloaded 555a229cd713433dafc6d36292412ff3.jpg
# Successfully downloaded 9a906c1f248fa3ece6f9ef308e90a243.jpg
# Successfully downloaded 3d2559bc74cd23b5b7fe8a461d69a281.jpg
# Successfully downloaded b636f5013f377bad4e40e4bcc6a049bc.jpg
# ...

# %% [markdown]
# # Download Images

# %%
chroma_instance.ingest_csv()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b98f87e0a262> in <cell line: 1>()
# ----> 1 chroma_instance.ingest_csv()
#
# /content/drive/MyDrive/art-finder/backend/src/database/setup_chroma.py in ingest_csv(self, csv_filename)
#      14   def ingest_csv(self, csv_filename: str = SCRAPED_CSV_SAVE_PATH ):
#      15       data, image_paths = csv_to_dict_list(csv_filename)
# ---> 16       self.collection.add(
#      17           documents=image_paths,
#      18           metadatas=data,
#
# /usr/local/lib/python3.10/dist-packages/chromadb/api/models/Collection.py in add(self, ids, embeddings, metadatas, documents)
#      93         """
#      94
# ---> 95         ids, embeddings, metadatas, documents = self._validate_embedding_set(
#      96             ids, embeddings, metadatas, documents
#      97         )
#
# ...

# %%
chroma_instance.collection.peek()
