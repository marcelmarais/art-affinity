# %%
# @title Colab Config
# !pip install open-clip-torch
# !pip install chromadb

import os
os.chdir('/content/drive/MyDrive/art-finder/backend/src') # PATH TO BACKEND GOES HERE
from database.setup_chroma import ChromaInstance

# %% [markdown]
# # Ingestion

# %%
chroma_instance = ChromaInstance()

# %%
chroma_instance.ingest_csv()

# %%
 chroma_instance.collection.peek()
# Out:
# {'ids': ['id_0',
#   'id_1',
#   'id_2',
#   'id_3',
#   'id_4',
#   'id_5',
#   'id_6',
#   'id_7',
#   'id_8',
#   'id_9'],
#  'embeddings': [[-0.05584124103188515,
#    0.14868728816509247,
#    -0.12363733351230621,
#    0.021751414984464645,
#    0.06139790266752243,
#    -0.06393234431743622,
#    0.007809024304151535,
#    -0.006517842411994934,
#    0.03204696998000145,
#    -0.04141775518655777,
#    -0.012422190047800541,
#    -0.008981265127658844,
#    0.04368672892451286,
#    0.02199080027639866,
#    -0.05180837959051132,
#    -0.02661951258778572,
#    0.011361095122992992,
#    0.03866177052259445,
#    -0.007326620630919933,
#    -0.055861227214336395,
#    -0.002988841151818633,
#    0.035090088844299316,
#    0.021890411153435707,
#    0.0356721505522728,
#    -0.05533095449209213,
#    -0.0019925027154386044,
#    -0.0058659701608121395,
#    -0.008587125688791275,
#    0.054653968662023544,
#    0.054491158574819565,
#    -0.05036427080631256,
# ...

# %%
ftyguhy8n t7t t7tt. y t7
# Out:
#   File "<ipython-input-5-b517e699b055>", line 1
#     ftyguhy8n t7t t7tt. y t7
#               ^
# SyntaxError: invalid syntax
